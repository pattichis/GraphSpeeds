# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/GraphSpeeds/blob/main/GraphSpeeds_lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Variables
#
# Run the following code by clicking on the play button inside [ ].
#
# What can you see?
#
# Comments are used for making notes:
#
# ```
# # After this special character, computer ignores the text.
# ```
#
# A variable is created using the following line:
# ```
# x = 3
# ```
# Thus, the variable <tt>x</tt> stores the value 3.</br>
# <b>Whenever we see <tt>x</tt>, remember that <tt>x</tt> holds the value of 3.</b>
#
# Note the special format</br>
# - The name of the variable is on the left of <tt>=</tt>.
# - On the right of <tt>=</tt>, we have an expression.
# - The computer will not understand <tt>3 = x</tt>, eventhough this is valid mathematically!
#
# We can see what <tt>x</tt> holds using:
# ```
# print(x)
# ```
#
# In programming, we say that <tt>print()</tt> is a
#  <b>function</b>.
#
# We say that the variable <tt>x</tt> is an argument to
#    <tt>print()</tt>.
#
# We can change what we print by changing the variable <tt>a</tt>.
#
# Carefully review the code line-by-line to understand how it works.
#
# ## Assignment: understanding comments and variables
# Study the code and answer the following:
# 1. Does the output change if you change a comment?
# 2. Note the () after print. What happens when you remove one of them or both?
# 3. What is the variable in the code?
# 4. Can you change the code so that it will print 5?

# %%
# Hello. This line is for humans to read.
# It is not to be executed.
# When you first type #, we have a comment. Typing here does not affect anything
# Comments are used to explain programs to humans.
# Computers do not execute the comments.

# Computers use variables to store information.
# In the following line, we store the number 3 in the variable "x"

# What do you understand by saying that "x" is a variable?
# Run this cell. Try a different value for "x".

# Create another variable and experiment with different values.

x = 5

# print the value of x
print(x)
# Out:
# 5

# %% [markdown]
# # Strings
#
# You can use variables to store characters.
#
# A collection of characters forms a string.
#
# So the following code stores your name in a variable:
#
#
# ```
# MyString = "A short phrase"
# ```
# From now on, MyString holds "A short phrase".
#
#
# Run the following code by clicking on the play button on the left.
#
# What can you see?
#
# Carefully read the code line-by-line to understand how it works.
#
# ## Assignment: understanding strings
# Modify the code and answer the following questions:
# 1. Can you change the code so that it will print your favorite food?
# 2. Can you change the name of the variable to <tt>food</tt> and then <tt>print(food)</tt>?

# %%
# STRINGS
# Computers understand strings.
# The following line creates a string and stores it in the variable MyString
MyString = "Hello World!"

# PRINTING
# You can now see the string in a:
print(MyString)
# Out:
# Hello World!

# %% [markdown]
# # Understanding rates
# Consider the following problem:
#
# a. Mike drives his car 60 km in 55 minutes. What is its average speed in kilometers per minute?
#
# We compute the average speed by dividing:
# ```
# distance = 60   # 60 km
# time     = 55   # 55 minutes
# rate = distance / time
# ```
# We can print multiple entries using commas:
# ```
# print("time = ", time, " distance = ", distance)
# ```
#
# ## Assignment: understanding rates
# Work on the following problems:
#
# b. A police car drives 236 km in 3 hours.
# What is its average speed in kilometers per hour?
#
# c. A train travels 39 miles in 35 minutes.
# What is its average speed in miles per minute?
#
# d. A Sea Anemone moves 2.34 inches in 6 hours. What is its rate of speed?

# %%
# SOLUTION for:
# a. Mike drives his car 60 km in 55 minutes.
# What is its average speed in kilometers per minute?

# Store the values in variables
distance = 60
time = 55
rate = distance / time

# print the calculation
print("rate = distance / time")
print("distance  = ", distance, " km")
print("time = ", time, " minutes")
print("rate = ", rate, " km/minute")
# Out:
# rate = distance / time
# distance  =  60  km
# time =  55  minutes
# rate =  1.0909090909090908  km/minute

# %%
# MODIFY the code to solve the following problem:
# b. A police car drives 236 km in 3 hours.
#    What is its average speed in kilometers per hour?

# Store the values in variables
distance = 236
time = 3
rate = distance / time

# print the calculation
print("Average speed = distance / time")
print("distance  = ", distance, " km")
print("time = ", time, " hours")
print("rate = ", rate, " km/hour")
# Out:
# Average speed = distance / time
# distance  =  236  km
# time =  3  hours
# rate =  78.66666666666667  km/hour

# %%
# MODIFY the code to solve the following problem:
# c. A train travels 39 miles in 35 minutes.
#    What is its average speed in miles per minute?

# Store the values in variables
distance = 60
time = 55
rate = distance / time

# print the calculation
print("rate = distance / time")
print("distance  = ", distance, " km")
print("time = ", time, " minutes")
print("rate = ", rate, " km/minute")
# Out:
# rate = distance / time
# distance  =  60  km
# time =  55  minutes
# rate =  1.0909090909090908  km/minute

# %%
# MODIFY the code to solve the following problem:
# d. A Sea Anemone moves 2.34 inches in 6 hours.
#    What is its rate of speed?

# Store the values in variables
distance = 60
time = 55
rate = distance / time

# print the calculation
print("rate = distance / time")
print("distance  = ", distance, " km")
print("time = ", time, " minutes")
print("rate = ", rate, " km/minute")
# Out:
# rate = distance / time
# distance  =  60  km
# time =  55  minutes
# rate =  1.0909090909090908  km/minute

# %% [markdown]
# # Compute distances from rates
# Consider the following problem:
#
# e. Sarah rides her bike with a constant speed of 9 km/h.
# How far can she travel in 4 hours?
#
# You can compute the distance from rates using time:
# ```
# rate = 9
# time = 4
# distance = rate*time
# ```
#
# ## Assignment: Compute distances from rates
# Modify the code to solve the following problems:
#
# f. An airplane flies with a constant speed of
# 398 mph.<br>
# How far can it travel in 3 and ½ hours?
#
# g. Abigail runs at a constant speed of 350 feet per minute.<br>
# How far can she travel in 32 minutes?
#
# h. A starfish was crawling around for 45 minutes. It moves 15 centimeters each minute. How far did it travel?

# %%
# SOLUTION for:
# e. Sarah rides her bike with a constant speed of 9 km/h.
# How far can she travel in 4 hours?

# Save the variables
rate = 9
time = 4

# Compute distance
distance = rate*time

print("distance = rate*time")
print("rate = ", rate, " km/h")
print("time = ", time, " hours")
print("distance = ", distance, " km")
# Out:
# distance = rate*time
# rate =  9  km/h
# time =  4  hours
# distance =  36  km

# %%
# MODIFY the code to solve:
# f. An airplane flies with a constant speed of 398 mph.
#   How far can it travel in 3 and ½ hours?

# Save the variables
rate = 9
time = 4

# Compute distance
distance = rate*time

print("distance = rate*time")
print("rate = ", rate, " km/h")
print("time = ", time, " hours")
print("distance = ", distance, " km")
# Out:
# distance = rate*time
# rate =  9  km/h
# time =  4  hours
# distance =  36  km

# %%
# MODIFY the code to solve:
# g. Abigail runs at a constant speed of 350 feet per minute.
# How far can she travel in 32 minutes?

# Save the variables
rate = 9
time = 4

# Compute distance
distance = rate*time

print("distance = rate*time")
print("rate = ", rate, " km/h")
print("time = ", time, " hours")
print("distance = ", distance, " km")
# Out:
# distance = rate*time
# rate =  9  km/h
# time =  4  hours
# distance =  36  km

# %%
# MODIFY the code to solve:
# h. A starfish was crawling around for 45 minutes.
#    It moves 15 centimeters each minute.
#    How far did it travel?

# Save the variables
rate = 9
time = 4

# Compute distance
distance = rate*time

print("distance = rate*time")
print("rate = ", rate, " km/h")
print("time = ", time, " hours")
print("distance = ", distance, " km")
# Out:
# distance = rate*time
# rate =  9  km/h
# time =  4  hours
# distance =  36  km

# %% [markdown]
# # Compute times from rates
# You can calculate time from rate and distance using:
#
# i. A train travels with a constant speed of 34 km/h.<br>
# How long will it take to travel a distance of 33.4 kilometers?
#
# ```
# rate = 34
# distance = 33.4
# time = distance / rate
# ```
# ## Assignment: Compute times from rates
# Modify the code below to solve:
#
# j. An airplane flies with a constant speed of
# 880 km/h.<br>
# How long will it take to travel a distance of 3652 kilometers?
#
# k. A car drives with a constant speed of
# 103 km/h.<br>
# How long will it take to travel a distance of 454.9 kilometers?
#
# l. Bob rides his motorcycle with a constant speed of 30 km/h.
# How long will it take to travel a distance of 17 kilometers?

# %%
# SOLUTION for:
# i. A train travels with a constant speed of 34 km/h.
# How long will it take to travel a distance of 33.4 kilometers?

rate = 34
distance = 33.4
time = distance / rate

print("time = distance / rate")
print("rate = ", rate, " km/h")
print("distance = ", distance, " km")
print("time = ", time, " hours")
# Out:
# time = distance / rate
# rate =  34  km/h
# distance =  33.4  km
# time =  0.9823529411764705  hours

# %%
# MODIFY the code to solve:
# j. An airplane flies with a constant speed of 880 km/h.
#    How long will it take to travel a distance of 3652 kilometers?

rate = 34
distance = 33.4
time = distance / rate

print("time = distance / rate")
print("rate = ", rate, " km/h")
print("distance = ", distance, " km")
print("time = ", time, " hours")
# Out:
# time = distance / rate
# rate =  34  km/h
# distance =  33.4  km
# time =  0.9823529411764705  hours

# %%
# MODIFY the code to solve:
# k. A car drives with a constant speed of 103 km/h.
#    How long will it take to travel a distance of 454.9 kilometers?

rate = 34
distance = 33.4
time = distance / rate

print("time = distance / rate")
print("rate = ", rate, " km/h")
print("distance = ", distance, " km")
print("time = ", time, " hours")
# Out:
# time = distance / rate
# rate =  34  km/h
# distance =  33.4  km
# time =  0.9823529411764705  hours

# %%
# MODIFY the code to solve:
# l. Bob rides his motorcycle with a constant speed of 30 km/h.
# How long will it take to travel a distance of 17 kilometers?

rate = 34
distance = 33.4
time = distance / rate

print("time = distance / rate")
print("rate = ", rate, " km/h")
print("distance = ", distance, " km")
print("time = ", time, " hours")
# Out:
# time = distance / rate
# rate =  34  km/h
# distance =  33.4  km
# time =  0.9823529411764705  hours

# %% [markdown]
# #4 Bonus: Decide which section should be used to solve these problems:
#
# m. Find speed when, distance is 142 km and time is 2 hours.
#
# n. Find out the distance covered when, speed is 960 km/hour and time is 5.5 hours.
#
# o. A cyclist covers 950 m in 5 minutes. Find his speed in km/ hour.
#
# p. Determine the time taken when, distance is 7150 km and speed is 780 km/hr.

# %%
# BONUS problem
# m. Find speed when, distance is 142 km and time is 2 hours.

# %%
# BONUS problem
# n. Find out the distance covered when, speed is 960 km/hour and time is 5.5 hours.

# %%
# BONUS problem
# o. A cyclist covers 950 m in 5 minutes. Find his speed in km/ hour.

# %%
# BONUS problem
# p. Determine the time taken when, distance is 7150 km and speed is 780 km/hr.

# %% [markdown]
# # Working with lists
#
# Python allows us to create lists of numbers.
# You can store each list in a variable.
#
# We put the numbers inside [ ], each separated by a ,
# ```
# A = [1, 2, 3]
# ```
#
# We can print the result:
# ```
# print(A)
# ```
#
# ## Assignment: Print a list
# Create and print a list of 2, 4, 6, 8.

# %%
# Create a list of numbers and store in A:
A = [1, 2, 3]

# We can see the list using print(.)
print(A)
# Out:
# [1, 2, 3]

# %%
# Print a list of the numbers 2, 4, 6, 8.

# %% [markdown]
# # List of strings
# We can also create a list of strings in the same way:
# ```
# Strings = ["tortilla", "breakfast burrito"]
# ```
#
# ## Assignment: Print a list of strings
# Run and study the following code.<br>
# Then, modify the code so that:
# 1. Enter three favorite foods.
# 2. Print all of the elements in the list.

# %%
Strings = ["tortilla", "breakfast burrito"]
print(Strings)
# Out:
# ['tortilla', 'breakfast burrito']

# %%
# Print a list of your favorite foods.

# %%
# Import the functions to use
from lineart_v3 import CreateVideo

# Decide which images and videos you want to put together:
img_list = ["race.mp4"]

# Set the duration for each one in seconds. Note: video durations are ignored.
durations_list = [1]

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Opening  race.mp4
# [ WARN:0@3.409] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ERROR:0@3.410] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(GSTREAMER): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
# video: height =  600  width =  800
# File 'all.mp4' has been removed.
# [ WARN:0@3.734] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (2180) open OpenCV | GStreamer warning: cannot link elements
# VideoWriter initialized successfully.
# [ WARN:0@4.076] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ERROR:0@4.076] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(GSTREAMER): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
#
#
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# 2024-03-07 19:37:03.213 python[15578:5987158] WARNING: -finishWriting should not be called on the main thread.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # Interpreting the video using time.
# Review the video and answer the following questions.
# 1. Pause the video at different times BEFORE the animals reach the end. Compare displayed times. What do you observe?
# 2. What happens to the displayed time after an animal reaches the end?
# 3. How long did each animal take to complete the race?

# %% [markdown]
# # Connecting the video using distance.
# Review the video and answer the following questions.
# 1. Pause the video at different times BEFORE the animals reach the end.
# - Compare the distances covered by each animal.
# - What is the distance covered by the fastest animal?
# - What is the distance covered by the slowest animal?
# 2. Wait for all of them finish.
# - Compare the distances covered by each animal. NOTE: some animals may cover slightly different distances.

# %% [markdown]
# # Interpreting the video using speeds.
# Review the video and answer the following questions.
# 1. Review the speeds for all of the animals. Then answer the following:
# - Which one has the highest speed?
# - Which one has the lowest speed?
# 2. Which animal covered the distance faster than everyone else?
# 3. Which animal covered the distance slower than everyone else?
# 4. Can you use the speeds to determine who comes first? Second? Third? Fourth? How?

# %% [markdown]
# # Compute times.
# Review the video and answer the following questions.
# 1. At the begining of the video, answer the following:
# - What is the time for each animal?
# - What is the distance covered by each animal?
# 2. At the end of the video, answer the following:
# - What is the distance covered by each animal?
# - What is their corresponding time?
# - Write down an equation for time using distance and speed:
# $$ \text{time} =\text{? in terms of speed and distance.}$$
# - Verify your equation works by the end of the video.

# %% [markdown]
# # Compute distances.
# Review the video and answer the following questions.
# 1. Pause the video at different times BEFORE an animal reaches the end. Answer:
# - Based on speed, who covers the largest distance?
# 2. Pause the video at time = 2 hours.
# - Can you determine the distance each animal travels using their speed?
# - Write down an equation for distance using time and speed:
# $$ \text{distance} = ? \text{ in terms of time and speed}. $$
# - Verify that your equation works by substituting time = 2 hours.
# 3. Pause the video at time = 1.5 hours. Answer:
# - Verify that your equation works by substituting time = 1 hour.

# %% [markdown]
# # Compute speeds.
# Review the video and answer the following questions.
# 1. Pause the video at different times BEFORE an animal reaches the end. Answer:
# - Based on distance, who travels at the highest speed?
# 2. Pause the video at time = 2 hours.
# - Can you determine the speed each animal travels using their distance?
# - Write down an equation for speed in terms of time and distance:
# $$ \text{speed} = ? \text{ in terms of distance and time}. $$
# - Verify that your equation works by substituting time = 2 hours.
# 3. Pause the video at time = 1.5 hours. Answer:
# - Verify that your equation works by substituting time = 1 hour.
