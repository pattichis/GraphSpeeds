# %% [markdown]
# <a href="https://colab.research.google.com/github/pattichis/GraphSpeeds/blob/main/GraphSpeeds_lesson_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup system
# Setup the system and get files from the internet.
#
# In the following code, we will download the necessary files from the internet.

# %%
# Install kaleido package
# !pip install -U kaleido

# Remove existing files
import os

# Stop pygame from opening a window
os.environ["SDL_VIDEODRIVER"] = "dummy"

VS_CODE = True  
if (not VS_CODE):
    os.chdir("/content/")
    #!find './' -maxdepth 1 -type f -delete
    
    # Mount the drive:
    from google.colab import drive
    drive.mount('/content/drive')
    
    # Use wget with -nc to avoid overwriting local copy.
    # !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/lineart_v3.py

# Import the functions to use
from lineart_v3 import table, simulationVideo, textImage, plotTablesLines, CreateVideo, changeVideoSpeed
# Out:
# Requirement already satisfied: kaleido in /Users/mariospattichis/anaconda3/envs/pytorch/lib/python3.10/site-packages (0.2.1)
# pygame 2.5.2 (SDL 2.28.3, Python 3.10.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# # Make images from text
# You can create many text frames and save them into different frames.<br>
# This is done using <tt>saveImage("filename.png")</tt> as given below:
# ```
# text = "A single line text."
# textImage("single-line.png", text)
# ```
# We can also create an image with multiple lines as given below:
# ```
# text = """First line.
# Second line.
# Third line."""
# textImage("multi-line.png", text)
# ```
#
# ## Assignment: Create text explanation images
# Study and discuss the code within your group.
# Then perform the following tasks:
# 1. Click on the file <tt>Single-line.png</tt> on the left to see the image.
# 2. Click on the file <tt>multi-line.png</tt> on the left to see the image.
# 3. Change the single-line image to say <tt>Hello!</tt>.
# 4. Change the single-line image to <tt>"hello.png"</tt> and verify that it works!
# 5. Change the multi-line image to the say <tt>Hello</tt> and <tt>I like coding</tt> in two lines.
# 6. Change the multi-line image to <tt>"multi.png"</tt> and verify that it works!

# %%
# A single line example
text = "A single line text"
textImage("Single-line.png", text)

# A multi line example
text = """First line
Second line
Third line
Fourth line
"""
textImage("multi-line.png", text)

# %% [markdown]
# # Make images from tables
# You can save an image using <tt>saveImage()</tt> as shown below:
# ```
# # Create and plot the tyler table first ...
# Squirrel.saveImage("squirrel-table.png")
# ```
# This will save the table in the file <tt>tyler.png</tt>.
#
# ## Assignment: Create a table image
# Study the code below.
# Then perform the following:
# 1. Click on the generated table image and open it.
# 2. Change the file name to <tt>"table.png"</tt>.
# 3. Verify that the changed name worked for you.

# %%
# Create a table for the squirrel data
Squirrel = table()

# Enter the table values:
Squirrel.column_labels = ["x (hours)", "y (miles)"]
Squirrel.data_values = [[1, 3, 4, 8], [11, 33, 44, 88]]

# Plot the table
Squirrel.plotTable()

# Save the image for the table
Squirrel.saveImage("squirrel-table.jpg")
# Out:
# Wrote  squirrel-table.jpg

# %% [markdown]
# # Make images from plots
# You can save an image by specifying the file using:<br>
# ```
# # Prepare the tables for the final plot ...
# plotTablesLines(...                     # ... other arguments
#                 img_name = 'plot.png')  # plot file name
# ```
# This will save the plot in the file <tt>plot.png</tt>.
#
# ## Assignment: Saving image plot
# Study the code below and find where the file image is stored.<br>
# Then do the following:
# 1. Click on the file name to view the file.
# 2. Change the file name to <tt>frame1.png</tt> and verify that it worked.

# %%
# Merge all of the tables

# Squirrel table
Squirrel = table()
Squirrel.column_labels = ["x (hours)", "y (miles)"]
Squirrel.data_values = [[1, 3, 4, 8], [11, 33, 44, 88]]

# Elephant table
Elephant = table()
Elephant.column_labels = ["x (hours)", "y (miles)"]
Elephant.data_values = [[3, 5, 6, 10], [18, 30, 36, 60]]

# Tortoise table
Tortoise = table()
Tortoise.column_labels = ["x (hours)", "y (miles)"]
Tortoise.data_values = [[3, 5, 8, 12], [3.6, 6, 9.6, 14.4]]

# Koala table
Koala = table()
Koala.column_labels = ["x (hours)", "y (miles)"]
Koala.data_values = [[1, 3, 5, 6], [6.2, 18.6, 31, 37.2]]


tables_list = [Squirrel, Elephant, Tortoise, Koala]

# Line equations of tables
legend_labels = [
      'Squirrel: y = 11*x',
      'Elephant: y = 6*x',
      'Tortoise: y = 1.2*x',
      'Koala:    y = 6.2*x']

# Plot tables
plotTablesLines(tables_list,
                fig_title = 'Compare speeds',              # title on top
                x_label = 'Elapsed time (hours)',             # appears along x-axis
                y_label = 'Distance in miles',          # appears along y-axis
                legend_title = 'Journey',                       # title on the right hand side
                legend_labels = legend_labels,                  # text describing the table
                img_name = 'plot.jpg')                          # plot image name

# %% [markdown]
# # Make race videos: find character images
# ## Find cute images for your characters and download them.
# You can use your own images for generating videos. <br>
#
# To do this, search on the internet :-)<br>
# Here is what I searched for in order to find my elephant image:
# ```
#     free cute elephant image facing right on white background
# ```
#
# You can download your images locally through the web address.
# Here is an example:
# ```
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Elephant.png
# ```
# <b>Careful: Save the </b>
#
# ## Assignment: Find character images
# Find the images that you want to use for your characters.<br>
# Then do the following:
# 1. Save the images in your local directory. Use <tt>wget</tt> to copy them here.
# 2. Click on the folder icon and then click on each image.
# 3. Confirm that you have downloaded each image.

# %% [markdown]
# # Working with image and videos in Google Colab

# %% [markdown]
# # How to upload images to Google Drive
#
# 1. Click on the folder icon on the left of your browser.
#
#
# <b>Folder icon</b>
# ![img1.png](data:image/png;base64,...)
#
# 2. Click on file upload icon to upload your picture.
#
# <b>Upload file icon</b>
# ![image.png](data:image/png;base64,...)

# %%
# ONLY use this code if you want to download a file from the internet.

# Only execute this once
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Elephant.png
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Squirrel.png
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Tortoise.jpg
# !wget -nc https://raw.githubusercontent.com/pattichis/GraphSpeeds/main/Koala.jpeg
# Out:
# File ‘Elephant.png’ already there; not retrieving.
#
# File ‘Squirrel.png’ already there; not retrieving.
#
# File ‘Tortoise.jpg’ already there; not retrieving.
#
# File ‘Koala.jpeg’ already there; not retrieving.

# %% [markdown]
# # Make race videos: place your characters
# ## Specify the images for each character and their speeds
# You can specify the name of each character using:
# ```
# Elephant.name = "Elephant"  # <- name of the character
# ```
# You can simply enter the names of the image that you downloaded using:
# ```
# Elephant.img = "Elephant.png"  # <- name of the file from the internet
# ```
# You then need to specify the speed for the elephant using:
# ```
# Elephant.speed = 6  # <- speed is just a number
# ```
#
# ## Place your characters on an image
# In order to build the video, you need to understand the size of your image:
# ```
#  600 pixels height means you have 600 rows from the top to the bottom.
#  800 pixels width  means you have 800 columns from left to right.
# ```
#
# You thus want to allocate a number of pixels so that you can put multiple pictures above each other.
#
# The recommendation is to use:
# ```
# target_size = 50
# ```
# This means that each character will take 50 pixels out of the 600 pixels for moving up and down.
#
# The next thing is to understand how to place your chacters!
# This is done by specifying the row and column.<br>
# ```
# Elephant.loc = (0, target_size)   # 0 is the leftmost column
#                                   # target_size is the bottom row of the character
# ```
#
# ## Assignment: place your characters
# 1. Enter the names for each character.
# 2. Enter the filenames from the characters that you downloaded.
# 3. Specify the speeds.
# 4. Study the placement. Do you need to change anything.

# %%
# Add all of the images

# Start with target_size
target_size = 50

# Elephant image
Elephant.name  = "Elephant"
Elephant.img   = "Elephant.png"
Elephant.speed = 6
Elephant.loc   = (0, target_size)   # row=target_size

Squirrel.name  = "Squirrel"
Squirrel.img   = "Squirrel.png"
Squirrel.speed = 11
Squirrel.loc   = (0, 3*target_size)

Tortoise.name  = "Tortoise"
Tortoise.img   = "Tortoise.jpg"
Tortoise.speed = 1.2
Tortoise.loc   = (0, 6*target_size)

Koala.name     = "Koala"
Koala.img      = "Koala.jpeg"
Koala.speed    = 6.2
Koala.loc      = (0, 9*target_size)

# %% [markdown]
# # Make race videos: make the video
# ## Find cute images for your characters and download them.
# Enter the list of elemants and names for your characters:
# ```
# merged_tables = [Elephant, Squirrel, Tortoise, Koala]
# ```
# Initialize the video:
# ```
# sim_video = simulationVideo(tables   = merged_tables,  # characters
#                              duration = 10,            # video duration in seconds
#                              race_distance = 100,      # simulation distance
#                              vid_title = "Race")       # video title
#
# ```
# You can then create and display the video using:
# ```
# video = sim_video.create_video()
# video.ipython_display()
# ```
#
#
# ## Assignment:
# Study the code below and find where the file images are stored.<br>
# Then do the following:
# 1. Click on the file name to view the file.

# %%
# Merge the updated tables
# Note the order in this list.
merged_tables = [Elephant, Squirrel, Tortoise, Koala]

# Initialize the video
sim_video = simulationVideo(tables   = merged_tables,  # characters
                             duration = 10,            # video duration in seconds
                             race_distance = 100,      # simulation distance
                             vid_title = "Race")       # video title

# You can then create and display the video using:
video = sim_video.create_video()
video.ipython_display()
# Out:
# File 'race.mp4' has been removed.
# [ WARN:0@4.933] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (2180) open OpenCV | GStreamer warning: cannot link elements
# VideoWriter initialized successfully.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# OpenCV: AVF: waiting to write video data.
# 2024-01-13 22:53:14.859 python[63322:11685785] WARNING: -finishWriting should not be called on the main thread.
# video file =  race.mp4  closed.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # Make race videos: experiment with your video
# In the previous run, one hour corresponded to one second of video.
#
# We can make the video go faster by having each second represent two hours.
#
# Tp do this, we can make <tt>simulation_speed=2.0</tt> by running:
# ```
# sim_video.set_video(video_name="new_race.mp4",  # new filename
#                     fps=10,                     # frames per second
#                     simulation_speed=2.0)       # speed of the simulation
# ```
# You can also customize the units (after running set_video) using:
# ```
# sim_video.set_units(distance_string="meters", time_string="seconds", speed_string="meters/second")
# ```
# As before, you can then create and display the video using:
# ```
# video = sim_video.create_video()
# video.ipython_display()
# ```
# ## Assignment: experiment with your video
# 1. Change <tt>simulation_speed</tt> to 2.0. What do you observe?
# 2. Change <tt>fps</tt> to 20. What do you observe?
# 3. Save the video to a different file name.
# 4. Change the distance to feet and the time to minutes.

# %%
# Experiment with the video:
sim_video.set_video(video_name="new_race.mp4",  # new filename
                    fps=10,                     # frames per second
                    simulation_speed=2.0)       # speed of the simulation

sim_video.set_units(distance_string="miles",
                    time_string="hours",
                    speed_string="miles/hour")


# Create and save your video:
video = sim_video.create_video()
video.ipython_display()
# Out:
# File 'new_race.mp4' has been removed.
# VideoWriter initialized successfully.
# [ WARN:0@8.575] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (2180) open OpenCV | GStreamer warning: cannot link elements
# 2024-01-13 22:53:18.311 python[63322:11685785] WARNING: -finishWriting should not be called on the main thread.
# video file =  new_race.mp4  closed.
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %% [markdown]
# # Make the final video
# You can make the final video by combining images and videos together.
# ```
# img_list = ["multi-line.png",  "plot.jpg", "video.mp4", "tyler.jpg"]
# ```
# Here, note the following:
# - multi-line.png is an image. The file name ends in .png
# - plot.jpg       is an image. The file name ends in .jpg
# - video.mp4      is a video. The file name ends in .mp4
# - tyler.jpg      is an image. The file name ends in .jpg
#
# For the images, we can specify how long to display each one.<br>
# Suppose that we want:
# - 2.0 seconds for multi-line.png.
# - 1.0 seconds for plot.jpg.
# - 1.0         for video.mp4. This number is IGNORED.
# - 1.0 seconds for tyler.jpg.
# We put all of these numbers in a list as given by:
# ```
# durations_list = [2, 1.0, 1.0, 1.0]
# ```
#
# We can now create the video using:
# ```
# video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
#                   file_list=img_list,         # This the list of images and files to combine.
#                   fps=10,                     # The number of frames per second.
#                   durations=durations_list)   # The duration for each one.
# ```
# We can then display the video using:
# ```
# video.ipython_display()
# ```
# ## Assignment: Make final video
# Follow the process to create your final video:
# 1. Determine which images and videos you want to use.
# 2. Determine the order. For example, what is displayed first, second, etc.
# 3. Create the <tt>img_list</tt> array with the file names.
# 4. Determine how many seconds you want to display each image.
# 5. Create the <tt>durations_list</tt> array to enter durations for each image (enter 1 for videos).
# 6. Determine the final video file name.
# 7. Determine the frames per second. Here, note that the fps should match the race video.
# 8. Run <tt>CreateVideo()</tt> and <tt>video.ipython_display()</tt> to debug your video.

# %%
# Decide which images and videos you want to put together:
img_list = ["multi-line.png",  "plot.jpg", "race.mp4", "Single-line.png"]

# Set the duration for each one in seconds. Note: video durations are ignored.
durations_list = [2, 1.0, 1.0, 1.0]

# Create the video:
video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
                  file_list=img_list,         # This the list of images and files to combine.
                  fps=10,                     # The number of frames per second.
                  durations=durations_list)   # The duration for each one.

# Display the video:
video.ipython_display()
# Out:
# Opening  multi-line.png
# Opening  plot.jpg
# Opening  ??race.mp4
# Error: Could not open video: file name =  ??race.mp4
# [ WARN:0@37.339] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap_gstreamer.cpp (862) isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# [ERROR:0@37.340] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(GSTREAMER): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
#
#
# OpenCV: Couldn't read video stream from file "??race.mp4"
# [ERROR:0@37.358] global /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/videoio/src/cap.cpp (166) open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.6.0) /private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_506zufg7xt/croots/recipe/opencv-suite_1664548331847/work/modules/core/src/utils/filesystem.cpp:580: error: (-213:The function/feature is not implemented)  in function 'exists'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 8
#       5 durations_list = [2, 1.0, 1.0, 1.0]
#       7 # Create the video:
# ----> 8 video=CreateVideo(video_name="all.mp4",       # This is file name of the final video.
#       9                   file_list=img_list,         # This the list of images and files to combine.
#      10                   fps=10,                     # The number of frames per second.
#      11                   durations=durations_list)   # The duration for each one.
#      13 # Display the video:
#      14 video.ipython_display()
#
# File ~/Dropbox/coding/Estrella_Python_Codes/lineart_v3.py:606, in CreateVideo(video_name, file_list, fps, durations)
#     604 if not cap.isOpened():
#     605   print("Error: Could not open video: file name = ", filename)
# --> 606   raise ValueError("file name = "+filename+" cannot be opened!")
#     608 # Get video properties
#     609 width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
#
# ValueError: file name = ??race.mp4 cannot be opened!

# %% [markdown]
# # Optional: Change the duration of the entire video
# You can speed up or slow down the final video!
# ```
# changeVideoSpeed("all.mp4", "all2.mp4", speed_factor=0.5)
# ```
# Note:
# - all.mp4  is the input video file.
# - all2.mp4 is a new, output video file.
# - speed_factor=0.5 will double the duration of the video.
# - speed_factor=2.0 will halve the duration of the video.
# - speed_factor=1.0 will not change anything.
# ## Optional Assignment: Change the duration of the entire video.
# Experiment with different speeds to determine which one you prefer.

# %%
changeVideoSpeed("all.mp4", "all2.mp4", speed_factor=0.5)

# %% [markdown]
# # Playing and downloading videos
#
# <b>Video controls</b>
# ![im1.png](data:image/png;base64,...)
#
# <b>Download File after you click on dots icon :</b>
# ![im2.png](data:image/png;base64,...)
